# %% [markdown]
# <div style="text-align: right;">© 2026 Moses Boudourides. All Rights Reserved.</div>
#
# # LLMs for Qualitative and Mixed-Methods Social Network Analysis (SNA)
# ## Moses Boudourides
#
# # Session 3: LLM Capabilities and Mixed-Methods Designs

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from pyvis.network import Network
import os
import json
import sys
import hashlib
import random
from sklearn.datasets import fetch_20newsgroups
import IPython
from openai import OpenAI
# import google.generativeai as genai

# %%
# --- 1. & 2. KEY LOADING & INITIALIZATION ---

# Force Google to use REST to avoid ALTS/GCP credential errors
os.environ["GOOGLE_API_USE_MTLS"] = "never" 

def get_api_key(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            return f.read().strip().replace('"', '').replace("'", "")
    return None

oa_key = get_api_key("openai_key.txt")
# gem_key = get_api_key("gemini_key.txt")

# Initialize OpenAI
client_oa = OpenAI(api_key=oa_key)

# # Initialize Gemini using 'rest' transport to bypass gRPC/ALTS errors
# genai.configure(api_key=gem_key, transport='rest')

# # Dynamic Model Selection
# available_models = [m.name for m in genai.list_models() if 'generateContent' in m.supported_generation_methods]
# target_model = 'gemini-1.5-flash' if 'models/gemini-1.5-flash' in available_models else available_models[0].split('/')[-1]
# model_gemini = genai.GenerativeModel(target_model)

# %% [markdown]
# ## Part 1: Qualitative Text Corpus and LLM-Assisted Analysis
#
# **Goal:**
# Demonstrate how LLMs can assist qualitative coding, memoing, and abductive reasoning—without replacing interpretation.
#
# This notebook uses OpenAI API for real LLM analysis. All LLM outputs are **provisional** and must be interpreted by the researcher.

# %%
# --- 3. DATA & PERSISTENT QUERY STEP ---

# Simulated interview excerpts describing relationships
texts = [
    "I rely on Alex when decisions become difficult.",
    "Jordan often undermines my authority in meetings.",
    "Sam provides emotional support but avoids formal responsibility.",
    "Alex and Jordan appear aligned publicly but compete privately."
]

df = pd.DataFrame({"text": texts})
df
# Out:
#                                                 text
# 0    I rely on Alex when decisions become difficult.
# 1  Jordan often undermines my authority in meetings.
# 2  Sam provides emotional support but avoids form...
# 3  Alex and Jordan appear aligned publicly but co...

# %% [markdown]
# ## LLM-Assisted Provisional Coding
#
# We ask the LLM to suggest relational codes. Codes are not final categories but provisional interpretations that the researcher must review and refine.

# %%
# 2. Persistence Logic
CACHE_FILE = "llm_cache_s3.json"

if os.path.exists(CACHE_FILE):
    with open(CACHE_FILE, "r") as f:
        cache = json.load(f)
else:
    cache = {}

def get_label(model_id, text, api_func, prompt_type="coding"):
    # Unique key ensures cache stays valid even if prompt or text changes
    cache_key = f"{model_id}_{prompt_type}_{text[:50]}"
    
    if cache_key in cache:
        return cache[cache_key]
    
    # Cache Miss: Call API
    result = api_func(text)
    cache[cache_key] = result
    
    # Save updated cache to disk
    with open(CACHE_FILE, "w") as f:
        json.dump(cache, f)
    return result

# 3. API Execution Wrappers
def query_openai_coding(text):
    prompt = f"""Propose provisional qualitative codes for social relationships in this excerpt. 
List only the codes, one per line, without explanation.

Text: {text}"""
    res = client_oa.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return res.choices[0].message.content.strip()

# 4. Run Process
print("Processing Qualitative Coding (Syncing Cache/API)...")
print()

for i, text in enumerate(texts):
    codes = get_label("openai", text, query_openai_coding, "coding")
    print(f"Text {i+1}: {text}")
    print(f"Provisional Codes:\n{codes}")
    print("-" * 60)

print("Status: All texts coded.")
# Out:
# Processing Qualitative Coding (Syncing Cache/API)...
#
# Text 1: I rely on Alex when decisions become difficult.
# Provisional Codes:
# - Dependence
# - Trust
# - Support
# - Decision-making partnership
# ------------------------------------------------------------
# Text 2: Jordan often undermines my authority in meetings.
# Provisional Codes:
# - Authority Undermined
# - Interpersonal Conflict
# - Power Dynamics
# - Professional Disrespect
# - Team Disruption
# - Communication Breakdown
# - Lack of Support
# ------------------------------------------------------------
# Text 3: Sam provides emotional support but avoids formal responsibility.
# Provisional Codes:
# - Emotional Support
# - Avoidance of Responsibility
# ------------------------------------------------------------
# Text 4: Alex and Jordan appear aligned publicly but compete privately.
# Provisional Codes:
# - Public Alignment
# - Private Competition
# - Social Facade
# - Interpersonal Dynamics
# - Hidden Rivalry
# ------------------------------------------------------------
# Status: All texts coded.

# %% [markdown]
# ## Relational Interpretation
#
# Beyond simple coding, we ask the LLM to interpret the relational meaning—the dynamics, power structures, and emotional undertones in the relationships described.

# %%
def query_openai_interpretation(text):
    prompt = f"""Interpret the relational dynamics in this excerpt. Identify:
1. The type of relationship (e.g., hierarchical, collegial, dependent)
2. The emotional or power dynamic
3. Any ambiguities or contradictions

Text: {text}"""
    res = client_oa.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return res.choices[0].message.content.strip()

print("Processing Relational Interpretation...")
print()

for i, text in enumerate(texts):
    interpretation = get_label("openai", text, query_openai_interpretation, "interpretation")
    print(f"Text {i+1}: {text}")
    print(f"Relational Interpretation:\n{interpretation}")
    print("-" * 60)
# Out:
# Processing Relational Interpretation...
#
# Text 1: I rely on Alex when decisions become difficult.
# Relational Interpretation:
# Based on the excerpt provided, here’s the interpretation of the relational dynamics:
#
# 1. **Type of Relationship**: The relationship appears to be **dependent**. The speaker indicates a reliance on Alex, suggesting that they look to him for support or guidance, particularly in challenging situations. This dynamic indicates that the speaker may view Alex as a source of expertise or authority in decision-making.
#
# 2. **Emotional or Power Dynamic**: The emotional dynamic suggests a level of trust and vulnerability from the speaker towards Alex. The speaker acknowledges their difficulty in making decisions, which implies a certain degree of insecurity or uncertainty. In terms of power dynamics, Alex may hold a position of influence or authority over the speaker, as the latter seeks assistance when faced with tough choices. This can create an imbalance, where Alex may have more power due to the speaker's dependence on him.
#
# 3. **Ambiguities or Contradictions**: One possible ambiguity in the statement is the lack of context regarding the nature of the decisions and the depth of the reliance on Alex. It is unclear whether this reliance is situational (only in difficult decisions) or if it reflects a broader pattern of dependency in their relationship. Additionally, the phrase could imply that while the speaker relies on Alex, they may also desire to become more independent in decision-making, leading to a potential internal conflict between dependence and self-sufficiency.
#
# Overall, the excerpt reveals a complex relationship characterized by dependence, trust, and potential ambiguity regarding the extent and implications of this reliance.
# ------------------------------------------------------------
# Text 2: Jordan often undermines my authority in meetings.
# Relational Interpretation:
# Based on the excerpt provided, here is an interpretation of the relational dynamics:
#
# 1. **Type of Relationship**: The relationship appears to be hierarchical. The speaker likely holds a position of authority that Jordan is expected to respect, but Jordan's actions indicate a challenge to that authority.
#
# 2. **Emotional or Power Dynamic**: The power dynamic suggests a conflict where the speaker feels their authority is being undermined. This creates an emotional tension, possibly leading to feelings of frustration, resentment, or insecurity for the speaker. Jordan's actions introduce a sense of rebellion or defiance, indicating a struggle for power or influence within the relationship.
#
# 3. **Ambiguities or Contradictions**: There may be ambiguity regarding Jordan's motivations for undermining the speaker's authority. It is unclear whether Jordan acts out of a desire for collaboration, personal ambition, or a belief that the speaker's authority is not warranted. Additionally, the term "undermines" suggests a deliberate action, but the context does not clarify whether this behavior is a consistent pattern or an isolated incident, leaving room for interpretation of Jordan's character and intentions.
# ------------------------------------------------------------
# Text 3: Sam provides emotional support but avoids formal responsibility.
# Relational Interpretation:
# Based on the excerpt provided, here’s an interpretation of the relational dynamics:
#
# 1. **Type of Relationship**: The relationship appears to be **collegial**. Sam offers emotional support, which suggests a level of camaraderie and collaboration. However, the avoidance of formal responsibility indicates that while there is a supportive element, it may not be one of equal accountability or commitment to shared tasks.
#
# 2. **Emotional or Power Dynamic**: The emotional dynamic leans towards a **supportive but unequal** power structure. Sam's provision of emotional support positions them as a figure of comfort, which can create a sense of reliance on their emotional presence. However, by avoiding formal responsibility, Sam maintains a degree of power by not being held accountable for any outcomes, which can create an imbalance where others may feel they need to depend on Sam without reciprocation in terms of responsibility.
#
# 3. **Ambiguities or Contradictions**: There is an inherent contradiction in Sam's role—while they are providing emotional support, which typically fosters a sense of closeness and mutual engagement, their avoidance of formal responsibility creates ambiguity. This could lead to confusion about the expectations within the relationship. Others may feel supported but uncertain about Sam’s commitment or reliability regarding formal tasks, potentially leading to frustration or dependency without clear boundaries.
#
# Overall, the dynamics suggest a complex interplay of support and avoidance that may affect the overall effectiveness and clarity of the relationship.
# ------------------------------------------------------------
# Text 4: Alex and Jordan appear aligned publicly but compete privately.
# Relational Interpretation:
# Based on the excerpt provided, here is an interpretation of the relational dynamics:
#
# 1. **Type of Relationship**: The relationship between Alex and Jordan seems to be **collegial** in a public context, as they appear to be aligned and possibly cooperating or presenting a united front. However, the mention of competition in private suggests a **complex dynamic** where there may be elements of rivalry or tension underlying their collegiality.
#
# 2. **Emotional or Power Dynamic**: The emotional dynamic can be characterized by **underlying tension**. While they portray unity in public, the private competition indicates a power struggle or desire for dominance, suggesting that both individuals may feel threatened by each other’s success or status. This could lead to feelings of insecurity or jealousy, impacting their interactions.
#
# 3. **Ambiguities or Contradictions**: There is a clear **contradiction** in the nature of their relationship; publicly, they present as allies, but privately, they engage in competition. This duality raises questions about the authenticity of their public alignment and whether it is a strategic façade to maintain a certain image. Additionally, the lack of clarity about the motivations behind their private competition leaves room for interpretation—are they competing for resources, recognition, or something else entirely?
#
# Overall, this excerpt highlights a multifaceted relationship characterized by both collaboration and competition, with emotional undertones that complicate their interactions.
# ------------------------------------------------------------

# %% [markdown]
# ## LLM-Assisted Memo Drafting
#
# We ask the LLM to draft a reflective memo that surfaces themes, suggests theoretical links, and identifies patterns across the corpus. The researcher must then interpret, contextualize, and theorize these insights.

# %%
def query_openai_memo():
    texts_str = "\n".join([f"- {t}" for t in texts])
    prompt = f"""Write a short analytic memo reflecting on power, trust, and ambiguity in these relationship descriptions.
Address themes that emerge across multiple texts.

Texts:
{texts_str}"""
    res = client_oa.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return res.choices[0].message.content.strip()

print("Generating Analytic Memo...")
print()

memo_key = "openai_memo_corpus"
if memo_key in cache:
    memo = cache[memo_key]
else:
    memo = query_openai_memo()
    cache[memo_key] = memo
    with open(CACHE_FILE, "w") as f:
        json.dump(cache, f)

print("ANALYTIC MEMO:")
print(memo)
print()
print("Note: The memo surfaces themes and suggests links. Researchers must edit, contextualize, and theorize.")
# Out:
# Generating Analytic Memo...
#
# ANALYTIC MEMO:
# **Analytic Memo: Power, Trust, and Ambiguity in Relationship Dynamics**
#
# **Introduction:**
# The relationships described across the four texts reveal complex dynamics of power, trust, and ambiguity that significantly influence decision-making and organizational coherence. By analyzing these themes, we can gain insights into how interpersonal relationships shape the dynamics of authority and support within a group.
#
# **Power Dynamics:**
# Power is a central theme in these relationships. The reliance on Alex during difficult decisions suggests a distribution of power based on expertise or emotional intelligence, indicating trust in Alex's judgment. This reliance implies a hierarchical structure where Alex holds a position of influence, albeit informally. In contrast, Jordan’s behavior undermines authority, suggesting a struggle for power that disrupts team cohesion. This power struggle complicates decision-making processes and may lead to an environment of uncertainty and conflict.
#
# The tension between Alex and Jordan also highlights competitive power dynamics. Their public alignment may serve to maintain a façade of unity, but the private competition suggests underlying rivalries that can destabilize trust within the group. This duality creates ambiguity, as team members may find it challenging to discern genuine alliances from strategic posturing.
#
# **Trust Issues:**
# Trust emerges as a critical element that affects the effectiveness of these relationships. The reliance on Alex indicates a foundation of trust, where the individual feels confident in Alex’s capabilities. However, Jordan's actions erode trust, both in terms of undermining authority and potentially creating a culture of insecurity among peers. When authority is publicly contested, it can lead to a lack of trust in leadership and decision-making processes.
#
# Sam’s role as a provider of emotional support, albeit without formal responsibility, introduces another layer of trust. While emotional support is crucial, the avoidance of formal responsibility may create ambiguity regarding Sam’s commitment to the group’s goals. This dynamic can foster a sense of reliability in emotional matters while simultaneously raising questions about accountability in decision-making contexts.
#
# **Ambiguity in Relationships:**
# Ambiguity is prevalent across these descriptions, particularly in the interplay between personal and professional roles. The public alignment between Alex and Jordan, juxtaposed with their private competition, creates a confusing landscape for team members. This duality may lead to misinterpretations of intentions and strategies, which can exacerbate conflicts and undermine trust.
#
# Furthermore, Sam’s dual role complicates the clarity of responsibilities within the group. While providing emotional support is undoubtedly valuable, the lack of formal accountability may leave others uncertain about where to turn for guidance or decision-making, leading to further ambiguity in the relationships.
#
# **Conclusion:**
# The themes of power, trust, and ambiguity are intricately woven into the fabric of these relationships. The reliance on specific individuals for support and decision-making illustrates the nuances of trust, while the competition and undermining behaviors highlight the complexities of power dynamics. Overall, these interrelated themes suggest that fostering an environment where clarity, accountability, and collaboration are prioritized may be essential for overcoming the challenges posed by ambiguity and power struggles. Addressing these dynamics can facilitate healthier relationships and enhance overall group effectiveness.
#
# Note: The memo surfaces themes and suggests links. Researchers must edit, contextualize, and theorize.

# %% [markdown]
# ## Abductive Reasoning and Anomaly Detection
#
# We ask the LLM to identify surprising or contradictory patterns. Abduction flags anomalies; researchers formulate hypotheses, return to data, and refine theory.

# %%
def query_openai_abduction():
    texts_str = "\n".join([f"- {t}" for t in texts])
    prompt = f"""Identify any surprising or contradictory relational patterns in these texts.
What patterns violate expectations? What tensions exist?

Texts:
{texts_str}"""
    res = client_oa.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return res.choices[0].message.content.strip()

print("Identifying Surprising Patterns (Abductive Reasoning)...")
print()

abduction_key = "openai_abduction_corpus"
if abduction_key in cache:
    abduction = cache[abduction_key]
else:
    abduction = query_openai_abduction()
    cache[abduction_key] = abduction
    with open(CACHE_FILE, "w") as f:
        json.dump(cache, f)

print("SURPRISING PATTERNS:")
print(abduction)
print()
print("Note: Abduction flags anomalies. Researchers formulate hypotheses, return to data, and refine theory.")
# Out:
# Identifying Surprising Patterns (Abductive Reasoning)...
#
# SURPRISING PATTERNS:
# The texts reveal several relational patterns that might be surprising or contradictory, as well as tensions that violate expectations:
#
# 1. **Dependence vs. Undermining**: The first text indicates a reliance on Alex during difficult decisions, suggesting trust and support. However, the second text highlights Jordan's behavior of undermining authority. This creates a tension between reliance on someone for support (Alex) and feeling undermined by another (Jordan), which could lead to conflicts or challenges in decision-making processes.
#
# 2. **Support vs. Responsibility**: The third text describes Sam as providing emotional support but avoiding formal responsibility. This pattern may violate the expectation that emotional support often comes with a willingness to take on responsibilities. This tension suggests a potential imbalance in the relationship dynamics, where emotional support is offered without a commitment to contribute in more structured or accountable ways.
#
# 3. **Public Alignment vs. Private Competition**: The fourth text points out that Alex and Jordan appear aligned publicly but compete privately. This contradiction raises questions about the authenticity of their public interactions and suggests underlying tensions in their relationship. The expectation that colleagues who present a united front are supportive of each other is violated here, indicating a more complex and possibly adversarial relationship beneath the surface.
#
# Overall, these texts illustrate a web of relational dynamics where dependency, authority, emotional support, and public versus private behavior create conflicting expectations and potential tensions in the relationships.
#
# Note: Abduction flags anomalies. Researchers formulate hypotheses, return to data, and refine theory.

# %% [markdown]
# ## Structural vs. Qualitative Anomalies
#
# We detect cases where structural equivalence (same network position) diverges from qualitative identity (different relational meanings). This is a key abductive prompt.

# %%
# Simulated node metadata from the qualitative analysis
nodes_metadata = {
    "Alex": {"role": "Advisor", "description": "Acts as a trusted confidant for difficult decisions."},
    "Jordan": {"role": "Advisor", "description": "Acts as a formal authority figure who undermines others."},
    "Sam": {"role": "Supporter", "description": "Provides emotional support but avoids formal responsibility."}
}

print("ANOMALY DETECTION: Structural Equivalence vs. Qualitative Identity")
print()

# Check for structural equivalents with divergent qualitative descriptions
for node_a in nodes_metadata:
    for node_b in nodes_metadata:
        if node_a < node_b:  # Avoid duplicates
            if nodes_metadata[node_a]["role"] == nodes_metadata[node_b]["role"]:
                if nodes_metadata[node_a]["description"] != nodes_metadata[node_b]["description"]:
                    print(f"ANOMALY DETECTED:")
                    print(f"  {node_a} and {node_b} have the same role ('{nodes_metadata[node_a]['role']}')")
                    print(f"  but divergent relational identities:")
                    print(f"    {node_a}: {nodes_metadata[node_a]['description']}")
                    print(f"    {node_b}: {nodes_metadata[node_b]['description']}")
                    print(f"  Research Question: How does this difference affect network dynamics?")
                    print()

print("Anomaly detection complete.")
# Out:
# ANOMALY DETECTION: Structural Equivalence vs. Qualitative Identity
#
# ANOMALY DETECTED:
#   Alex and Jordan have the same role ('Advisor')
#   but divergent relational identities:
#     Alex: Acts as a trusted confidant for difficult decisions.
#     Jordan: Acts as a formal authority figure who undermines others.
#   Research Question: How does this difference affect network dynamics?
#
# Anomaly detection complete.

# %% [markdown]
# ## Bias and Hallucination Check
#
# Critical limitations of LLMs include hallucination and normalization of certain patterns. Researchers must ask:
# - Does the LLM infer motives not in the data?
# - Does it normalize certain relational patterns?
# - Does it erase ambiguity?
#
# Scaling magnifies these risks.

# %%
print("BIAS AND HALLUCINATION REFLECTION")
print()
print("Questions for the researcher:")
print("1. Did the LLM infer motives or relationships not explicitly stated in the texts?")
print("2. Did the LLM normalize certain power dynamics as 'natural' or 'expected'?")
print("3. Did the LLM erase ambiguity by forcing clear categories?")
print("4. Are there cultural or contextual biases in the LLM's interpretations?")
print()
print("Recommendation: Always validate LLM outputs against the original texts.")
print("Maintain interpretive control and theoretical sensitivity.")
# Out:
# BIAS AND HALLUCINATION REFLECTION
#
# Questions for the researcher:
# 1. Did the LLM infer motives or relationships not explicitly stated in the texts?
# 2. Did the LLM normalize certain power dynamics as 'natural' or 'expected'?
# 3. Did the LLM erase ambiguity by forcing clear categories?
# 4. Are there cultural or contextual biases in the LLM's interpretations?
#
# Recommendation: Always validate LLM outputs against the original texts.
# Maintain interpretive control and theoretical sensitivity.

# %% [markdown]
# ## Session 3 Takeaway
#
# LLMs can assist coding, memoing, and abductive exploration. They do not replace:
# - Theoretical sensitivity
# - Interpretive judgment
# - Reflexive responsibility

# %% [markdown]
# ## Part 2: Applying Mixed-Methods Analysis to 20 Newsgroups Dataset
#
# Now we apply the same LLM-assisted qualitative and mixed-methods approaches to a larger dataset: the 20 Newsgroups corpus.

# %%
# --- CONFIGURATION ---
n = 20  # Number of Nodes (Researchers)
m = 100  # Number of Edges (Interactions/posts)

# Dataset Description (Formal Comment for Seminar)
# The 20 Newsgroups dataset is a collection of approximately 18,000 newsgroup posts 
# that originated in the early days of the internet (Usenet) and they can be 
# displayed as a social network (a directed weighted multigraph) among thousands 
# of unique nodes/researchers interacting/replying in the posts of the 20 newsgroups.
# Taken from sklearn.datasets.fetch_20newsgroups

# Generate a unique filename based on m to avoid mixing samples
config_hash = hashlib.md5(f"{m}_newsgroups_s3".encode()).hexdigest()[:8]
SNAPSHOT_FILE = f"news_snapshot_m{m}_{config_hash}.csv"

# CHECK IF WE ALREADY HAVE THE COMPLETE DATA
if os.path.exists(SNAPSHOT_FILE):
    print(f"✅ LOADING PERMANENT SNAPSHOT: {SNAPSHOT_FILE}")
    interactions = pd.read_csv(SNAPSHOT_FILE)
else:
    print(f"🚀 SNAPSHOT NOT FOUND. GENERATING NEW SAMPLE...")
    
    # 1. Fetch the big dataset (11,000+ posts)
    newsgroups = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
    full_df = pd.DataFrame({'text': newsgroups.data})
    
    # 2. Filter and Sample M posts
    df = full_df[full_df['text'].str.strip().str.len() > 20].copy()
    subset = df.sample(n=m, random_state=42).reset_index(drop=True)
    
    # 3. Assign the Social Structure (Source/Target)
    user_pool = [f"Researcher_{i:02d}" for i in range(n)]
    sources = [random.choice(user_pool) for _ in range(m)]
    targets = [random.choice([u for u in user_pool if u != s]) for s in sources]

    interactions = pd.DataFrame({
        "source": sources,
        "target": targets,
        "text": subset['text'].str[:300].replace('\n', ' ', regex=True)
    })

    # 4. IMMEDIATELY SAVE (before LLM processing)
    interactions.to_csv(SNAPSHOT_FILE, index=False)
    print(f"💾 PERMANENTLY SAVED: {SNAPSHOT_FILE}")

print(f"\n--- READY: {len(interactions)} interactions between {n} nodes ---")
interactions.head()
# Out:
# 🚀 SNAPSHOT NOT FOUND. GENERATING NEW SAMPLE...
# 💾 PERMANENTLY SAVED: news_snapshot_m100_715b7bf8.csv
#
# --- READY: 100 interactions between 20 nodes ---
#           source         target  \
# 0  Researcher_16  Researcher_08
# 1  Researcher_04  Researcher_19
# 2  Researcher_02  Researcher_10
# 3  Researcher_10  Researcher_17
# 4  Researcher_16  Researcher_10
#
#                                                 text
# 0  In case you missed it on the news....the first...
# 1       We have no way of knowing because we cann...
# 2    The lengthy article you quote doesn't imply ...
# 3  The recent rise of nostalgia in this group, co...
# 4  # ## Absolutely nothing, seeing as there is no...

# %% [markdown]
# ## LLM-Assisted Coding on Newsgroups Data
#
# Apply the same provisional coding approach to a sample of newsgroup posts to identify relational codes.

# %%
print("Processing Qualitative Coding on Newsgroups Sample...")
print()

# Sample a subset for detailed coding analysis
sample_size = min(5, len(interactions))
sample_interactions = interactions.sample(n=sample_size, random_state=42)

for idx, row in sample_interactions.iterrows():
    text = row['text']
    codes = get_label("openai", text, query_openai_coding, "coding_newsgroups")
    print(f"Post {idx}: {text[:80]}...")
    print(f"Codes: {codes}")
    print("-" * 60)

print("Coding sample complete.")
# Out:
# Processing Qualitative Coding on Newsgroups Sample...
#
# Post 83:     Ok boys & girls, hang on; here we go!      Christ's Eternal Gospel          ...
# Codes: - Group dynamics
# - Authority figures
# - Collaboration
# - Intellectual exchange
# - Scholarly relationships
# - Shared beliefs
# - Community identity
# - Educational interaction
# ------------------------------------------------------------
# Post 53:     J.N. Darby was one of the founders of the "Plymouth Brethren" and an early s...
# Codes: - Foundational Influence
# - Supportive Relationships
# - Translation Collaboration
# - Approval and Endorsement
# - Multilingual Engagement
# - Historical Context
# - Scholarly Contribution
# ------------------------------------------------------------
# Post 70:  I missed the presentations given in the morning session (when Shea gave his "ra...
# Codes: - Absence
# - Critique
# - Presence
# - Small group dynamics
# - Communication tools
# - Speaker-audience interaction
# - Panel discussion
# ------------------------------------------------------------
# Post 45:  I think the original poster meant opening the mouse, not just releasing the bal...
# Codes: - Clarification
# - Experience Sharing
# - Problem-Solving
# - Inquiry
# - Technical Knowledge
# - Community Engagement
# - Support Seeking
# ------------------------------------------------------------
# Post 44:   [After a small refresh Hasan got on the track again.]        |>    |> I get th...
# Codes: - Reflection
# - Regret
# - Withdrawal
# - Judgment
# - Self-preservation
# - Logic
# - Social dynamics
# ------------------------------------------------------------
# Coding sample complete.

# %% [markdown]
# ## Relational Interpretation on Newsgroups Data
#
# Interpret the relational dynamics and power structures in newsgroup interactions.

# %%
print("Processing Relational Interpretation on Newsgroups Sample...")
print()

for idx, row in sample_interactions.iterrows():
    text = row['text']
    interpretation = get_label("openai", text, query_openai_interpretation, "interpretation_newsgroups")
    print(f"Post {idx}: {text[:80]}...")
    print(f"Interpretation: {interpretation}")
    print("-" * 60)

print("Interpretation sample complete.")
# Out:
# Processing Relational Interpretation on Newsgroups Sample...
#
# Post 83:     Ok boys & girls, hang on; here we go!      Christ's Eternal Gospel          ...
# Interpretation: Based on the provided excerpt, here’s an interpretation of the relational dynamics:
#
# 1. **Type of Relationship**:
#    - The relationship appears to be **collegial**, as indicated by the informal greeting ("Ok boys & girls") and the collaborative nature of discussing academic topics (e.g., the Dead Sea Scrolls, biblical texts). This suggests a group dynamic where individuals are likely peers or colleagues engaging in a shared intellectual pursuit.
#
# 2. **Emotional or Power Dynamic**:
#    - The emotional tone is **enthusiastic and informal**, which may suggest a friendly and engaging atmosphere among the participants. However, the use of multiple names associated with scholarly works hints at varying levels of expertise and authority, which could imply a subtle **power dynamic** where certain individuals (possibly the authors of the works mentioned) hold more weight in the discussion. Nonetheless, the inclusive language suggests an effort to promote participation from all members, indicating a more balanced power dynamic overall.
#
# 3. **Ambiguities or Contradictions**:
#    - There are a few ambiguities present. For instance, the phrase "Ok boys & girls" could be seen as casual and inclusive, but it may also unintentionally trivialize the seriousness of the academic discussion that follows. Additionally, while the list of works indicates collaboration, the presence of multiple authors with different academic focuses (e.g., Robinson, Eisenman, LaSor) may introduce a contradiction in terms of how unified or cohesive the discussion is—whether it is a collaborative exploration or a more fragmented dialogue with diverse perspectives.
#
# Overall, the excerpt suggests a collegial relationship characterized by enthusiasm but with underlying complexities regarding authority and the nature of the discussion.
# ------------------------------------------------------------
# Post 53:     J.N. Darby was one of the founders of the "Plymouth Brethren" and an early s...
# Interpretation: Based on the provided excerpt, we can interpret the relational dynamics as follows:
#
# 1. **Type of Relationship**:
#    - The relationship between J.N. Darby and F.F. Bruce appears to be collegial. Both figures are involved in the field of biblical translation and interpretation, suggesting a level of mutual respect and professional acknowledgment, particularly as Bruce expresses approval of Darby’s work.
#
# 2. **Emotional or Power Dynamic**:
#    - The emotional dynamic seems to lean towards admiration or respect, especially given that Bruce "highly approved" of Darby’s translation. This indicates a recognition of Darby's contributions to biblical scholarship. However, there is also a subtle power dynamic at play, as Bruce’s approval can lend weight to Darby’s work within scholarly circles, positioning Bruce as a more contemporary authority who validates Darby’s earlier contributions.
#
# 3. **Ambiguities or Contradictions**:
#    - There are a few ambiguities in the excerpt. First, the phrase "the same fellow who did Young's Concordance" implies a connection between Darby and Young, which might suggest further relationships within the scholarly community, but it does not clarify their direct relationship. This could lead to confusion about whether Young's work is being equated with Darby's in terms of significance or quality. Additionally, the term "standard" regarding Young's Concordance raises questions about what it means for a work to be a "standard" and whether that status applies equally to Darby’s translation or if it is distinct in its own right. This lack of clarity could lead to differing interpretations among readers regarding the hierarchy of contributions within the field.
# ------------------------------------------------------------
# Post 70:  I missed the presentations given in the morning session (when Shea gave his "ra...
# Interpretation: Based on the provided excerpt, here’s a breakdown of the relational dynamics:
#
# 1. **Type of Relationship**:
#    - The relationship appears to be **collegial**. The speaker (Shea) and the audience or panel members are likely colleagues within a professional or academic context. This is suggested by the informal tone and the presence of a panel discussion format, indicating a level of equality among participants.
#
# 2. **Emotional or Power Dynamic**:
#    - The emotional dynamic includes a sense of **criticism** or **discontent** regarding Shea's presentation, as indicated by the phrases "rambling" and "almost inaudible." This suggests that the speaker may feel frustrated or dismissive towards Shea's ability to communicate effectively. The power dynamic seems to be somewhat **unequal**, as one individual (Shea) is positioned as the speaker while others are listeners, but the negative commentary implies a lack of respect or authority attributed to Shea in this specific context.
#
# 3. **Ambiguities or Contradictions**:
#    - There is a contradiction between the expectation of a presentation and the actual delivery, particularly noted by the description of Shea’s presentation as "rambling and almost inaudible." This raises questions about the effectiveness of Shea's communication skills and whether he is perceived as a credible speaker. Additionally, the narrator's attendance at the afternoon session, after missing the morning one, could imply a selective engagement—suggesting either a lack of commitment to the overall meeting or a focus on different presentations, which adds ambiguity to the narrator's investment in the event.
#
# Overall, the relational dynamics illustrate a collegial setting marked by underlying tensions and critiques regarding communication effectiveness and respect within the professional hierarchy.
# ------------------------------------------------------------
# Post 45:  I think the original poster meant opening the mouse, not just releasing the bal...
# Interpretation: Based on the provided excerpt, here’s an interpretation of the relational dynamics:
#
# 1. **Type of Relationship**: The relationship appears to be **collegial**. The speaker is engaging in a discussion or exchange of knowledge with another individual (the original poster), indicating a level of peer interaction rather than a hierarchical or dependent relationship.
#
# 2. **Emotional or Power Dynamic**: The emotional dynamic seems to be one of **collaboration and support**. The speaker is offering additional information and insights that could help the original poster, suggesting a willingness to assist and share knowledge. There is no overt power dynamic present, as both parties appear to be on equal footing in the context of the discussion.
#
# 3. **Ambiguities or Contradictions**: There are a few ambiguities in the excerpt. First, it is unclear whether the original poster has indeed found an answer to their query, as the speaker expresses a conditional willingness to ask further questions about a new ergonomic mouse. This could imply uncertainty about the original poster's knowledge or experience. Additionally, the mention of both the "original ADB mouse" and the "new ergonomic mouse" introduces a potential contradiction in terms of technology evolution; what applies to one may not necessarily apply to the other, which could lead to confusion regarding the cleaning methods being discussed.
#
# Overall, the interaction reflects a cooperative exchange of technical advice with some uncertainties regarding the original poster's knowledge and the applicability of the information shared.
# ------------------------------------------------------------
# Post 44:   [After a small refresh Hasan got on the track again.]        |>    |> I get th...
# Interpretation: Based on the provided excerpt, here’s the interpretation of the relational dynamics:
#
# 1. **Type of Relationship**: The relationship appears to be **hierarchical**. The speaker seems to hold a position of authority or superiority over Hasan, suggesting a dynamic where the speaker has the upper hand in terms of judgment or social standing.
#
# 2. **Emotional or Power Dynamic**: The emotional dynamic is somewhat condescending and critical. The speaker expresses a sense of superiority by stating that letting Hasan "drop the thread" might save him a "miniscule portion of his sorry face," which implies that Hasan is in a position of shame or embarrassment. The use of "sorry face" indicates a power dynamic where the speaker feels justified in judging Hasan's actions, reflecting an emotion of disdain or disappointment.
#
# 3. **Ambiguities or Contradictions**: There is a contradiction in the speaker's self-identification as a "logical person" while simultaneously engaging in a somewhat sarcastic and judgmental tone towards Hasan. It raises questions about the sincerity of the speaker's claim to rationality when their emotional response is clearly influencing their perspective. Additionally, the phrase "let him" suggests a willingness to allow Hasan to retreat or avoid confrontation, which could imply a level of compassion or understanding beneath the critical exterior, adding a layer of complexity to the relationship.
# ------------------------------------------------------------
# Interpretation sample complete.

# %% [markdown]
# ## Analytic Memo on Newsgroups Discourse
#
# Generate a reflective memo on the themes and patterns emerging from the newsgroups sample.

# %%
def query_openai_newsgroups_memo():
    sample_texts = "\n".join([f"- {row['text'][:100]}..." for _, row in sample_interactions.iterrows()])
    prompt = f"""Write a short analytic memo reflecting on the themes, tensions, and relational dynamics 
in these newsgroup posts. What patterns of discourse emerge?

Posts:
{sample_texts}"""
    res = client_oa.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return res.choices[0].message.content.strip()

print("Generating Analytic Memo on Newsgroups Discourse...")
print()

memo_ng_key = "openai_memo_newsgroups_sample"
if memo_ng_key in cache:
    memo_ng = cache[memo_ng_key]
else:
    memo_ng = query_openai_newsgroups_memo()
    cache[memo_ng_key] = memo_ng
    with open(CACHE_FILE, "w") as f:
        json.dump(cache, f)

print("ANALYTIC MEMO ON NEWSGROUPS DISCOURSE:")
print(memo_ng)
print()
print("Note: Researchers must contextualize and theorize these insights.")
# Out:
# Generating Analytic Memo on Newsgroups Discourse...
#
# ANALYTIC MEMO ON NEWSGROUPS DISCOURSE:
# **Analytic Memo: Reflections on Themes, Tensions, and Relational Dynamics in Newsgroup Posts**
#
# **Introduction:**
# The examined newsgroup posts reveal a complex tapestry of themes, tensions, and relational dynamics among participants. The discourse is characterized by an interplay of religious discussions, personal impressions, and technical exchanges, suggesting a community grappling with both ideological and practical matters.
#
# **Themes:**
# 1. **Religious Discourse and Authority:**
#    The reference to J.N. Darby and the "Plymouth Brethren" indicates a strong undercurrent of religious debate, suggesting that discussions around doctrinal interpretations and historical theological figures are central to this community. The mention of “Christ's Eternal Gospel” implies a commitment to exploring or defending particular beliefs, which can foster both unity and division among participants.
#
# 2. **Frustration and Critique:**
#    The post regarding the missed presentations and critiques of Shea's “rambling” suggests a tension between expectations and reality within the group. This indicates a desire for clarity and substance in discussions, as well as a potential frustration with perceived inefficiencies in communication or presentation styles.
#
# 3. **Technical Communication:**
#    The reference to "opening the mouse" indicates a conversation that includes practical, technical advice, hinting at a community that values sharing knowledge on various subjects, including technology. This discourse can create a sense of camaraderie as members collectively navigate challenges.
#
# **Tensions:**
# 1. **Ideological Disagreement:**
#    The posts reflect a tension between differing interpretations of religious doctrine, particularly in the context of the Plymouth Brethren. This can lead to conflict, as members may hold divergent views on important theological matters, creating an atmosphere of debate that is both passionate and potentially divisive.
#
# 2. **Communication Style:**
#    The critique of Shea’s presentation highlights a tension between informal and formal communication styles within the group. Participants may have varying preferences for how discussions are conducted, which can lead to misunderstandings and frustration when expectations are not met.
#
# 3. **Participation and Engagement:**
#    The mention of missed presentations points to a broader issue of engagement within the community. This suggests that there may be disparities in participation levels, which can lead to feelings of exclusion or disconnect among members who are unable to fully engage with the ongoing discussions.
#
# **Relational Dynamics:**
# 1. **Community Cohesion vs. Fragmentation:**
#    The blend of technical advice and theological discussion illustrates a duality in the community's identity. While there is a shared interest that binds members together, the ideological disagreements can also lead to fragmentation, as individuals may align themselves with particular factions within the broader conversation.
#
# 2. **Mentorship and Guidance:**
#    The supportive tone in some posts, particularly where advice is offered, highlights a dynamic of mentorship and guidance within the group. This indicates that more experienced members may take on roles as guides, helping others navigate both theological and practical challenges.
#
# 3. **Informal Hierarchies:**
#    The interplay of critiques suggests the emergence of informal hierarchies based on knowledge, communication style, and engagement levels. Members who are more articulate or knowledgeable may dominate discussions, which could influence the dynamics of power and influence within the group.
#
# **Patterns of Discourse:**
# The posts reveal patterns of discourse that oscillate between scholarly theological debate and pragmatic problem-solving. The community's communication tends to reflect a blend of seriousness regarding doctrinal discussions with a casual, sometimes humorous approach to technical issues. The diversity of topics and the varying levels of engagement among members suggest a rich, albeit complex, tapestry of interactions that define the newsgroup's culture.
#
# **Conclusion:**
# Overall, the newsgroup posts encapsulate a vibrant community navigating the intricate dynamics of faith, communication, and technical expertise. The themes of religious authority, critique, and practical advice coexist, creating a multifaceted environment that fosters both connection and contention. As members continue to engage, the challenge will be to balance these various elements to maintain a cohesive and supportive community.
#
# Note: Researchers must contextualize and theorize these insights.

# %% [markdown]
# ## Abductive Analysis on Newsgroups Data
#
# Identify surprising patterns and anomalies in the newsgroups interactions.

# %%
def query_openai_newsgroups_abduction():
    sample_texts = "\n".join([f"- {row['text'][:100]}..." for _, row in sample_interactions.iterrows()])
    prompt = f"""Identify any surprising, contradictory, or unexpected patterns in these newsgroup posts.
What tensions or anomalies exist in the discourse?

Posts:
{sample_texts}"""
    res = client_oa.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )
    return res.choices[0].message.content.strip()

print("Identifying Surprising Patterns in Newsgroups...")
print()

abduction_ng_key = "openai_abduction_newsgroups_sample"
if abduction_ng_key in cache:
    abduction_ng = cache[abduction_ng_key]
else:
    abduction_ng = query_openai_newsgroups_abduction()
    cache[abduction_ng_key] = abduction_ng
    with open(CACHE_FILE, "w") as f:
        json.dump(cache, f)

print("SURPRISING PATTERNS IN NEWSGROUPS:")
print(abduction_ng)
print()
print("Note: These anomalies prompt further investigation and theory refinement.")
# Out:
# Identifying Surprising Patterns in Newsgroups...
#
# SURPRISING PATTERNS IN NEWSGROUPS:
# Analyzing the newsgroup posts, several surprising, contradictory, or unexpected patterns emerge, revealing underlying tensions and anomalies in the discourse.
#
# 1. **Diverse Topics and Perspectives**: The posts cover a wide range of subjects, from religious discussions about Christ and J.N. Darby to technical issues related to computer mice. This diversity suggests a lack of focus within the group, leading to confusion about the central theme of the discussion. The sudden transition from theological discourse to technical troubleshooting indicates that participants may have varied interests, which could create tension as contributors struggle to follow or engage with topics outside their expertise.
#
# 2. **Tone and Engagement**: The first post has an excited tone, indicated by "Ok boys & girls, hang on; here we go!" This contrasts sharply with the more critical and somewhat dismissive tone in the third post, which describes a presentation as a "rambling and almost incoherent." This tension between enthusiasm and criticism may reflect differing expectations about the quality of contributions and the level of engagement required from participants.
#
# 3. **Miscommunication and Clarification**: The fourth post highlights a potential misunderstanding regarding the original poster's intent ("I think the original poster meant opening the mouse..."). This reveals an anomaly in communication where assumptions about the shared knowledge or context among participants may lead to misinterpretations. The need for clarifications suggests a disconnect in the group's ability to communicate effectively, which can contribute to frustration and alienation among members.
#
# 4. **Shifts in Focus**: The phrase "[After a small refresh Hasan got on the track again.]" implies a moment of disruption followed by a return to focus, which can be interpreted as indicative of the group’s dynamics. It suggests that while some members may struggle to stay on topic or keep up with the flow of conversation, others are able to re-engage and contribute meaningfully. This creates an uneven landscape of participation, where some voices dominate while others may feel marginalized.
#
# In summary, the posts reveal a tapestry of conflicting tones, varying levels of engagement, and an overarching challenge in maintaining a coherent discourse. These tensions highlight the complexities of group communication in an online setting, where diverse interests and communication styles can lead to both collaboration and discord.
#
# Note: These anomalies prompt further investigation and theory refinement.

# %% [markdown]
# ## Network Construction from Newsgroups Data
#
# Build a directed graph from the newsgroups interactions to visualize the social network structure.

# %%
# Build the Graph from all interactions
G = nx.from_pandas_edgelist(interactions, 'source', 'target', 
                            create_using=nx.DiGraph())

print(f"Graph Statistics:")
print(f"Nodes: {G.number_of_nodes()}")
print(f"Edges: {G.number_of_edges()}")
print(f"Density: {nx.density(G):.3f}")
print()

# Print first 10 edges
print("Sample edges:")
for i, e in enumerate(G.edges(data=True)):
    if i < 10:
        print(e)
# Out:
# Graph Statistics:
# Nodes: 20
# Edges: 88
# Density: 0.232
#
# Sample edges:
# ('Researcher_16', 'Researcher_08', {})
# ('Researcher_16', 'Researcher_10', {})
# ('Researcher_16', 'Researcher_02', {})
# ('Researcher_16', 'Researcher_01', {})
# ('Researcher_16', 'Researcher_09', {})
# ('Researcher_16', 'Researcher_04', {})
# ('Researcher_16', 'Researcher_07', {})
# ('Researcher_16', 'Researcher_06', {})
# ('Researcher_08', 'Researcher_00', {})
# ('Researcher_08', 'Researcher_06', {})

# %% [markdown]
# ## Network Visualization
#
# Visualize the newsgroups social network using pyvis.

# %%
# Initialize Network
net = Network(height="500px", width="100%", directed=True, bgcolor="#ffffff")

# Add Nodes (labels only, no visible circles)
for node in G.nodes():
    net.add_node(
        node, 
        label=node, 
        shape='dot',
        size=1,
        color='#ffffff',
        borderWidth=0,
        font={'size': 12, 'color': 'black', 'align': 'center'}
    )
    
# Add Edges
for source, target in G.edges():
    net.add_edge(
        source, 
        target, 
        color='#848484',
        arrows={'to': {'enabled': True, 'scaleFactor': 0.5}},
        smooth={'type': 'curvedCW', 'roundness': 0.2},
        font={'align': 'top', 'size': 12, 'color': 'blue'}
    )

# Physics and Rendering
net.set_options("""
var options = {
  "physics": {
    "barnesHut": { "gravitationalConstant": -3000, "springLength": 150 }
  }
}
""")

html_content = net.generate_html()
with open("newsgroups_graph_s3.html", "w") as f:
    f.write(html_content)

IPython.display.IFrame(src="newsgroups_graph_s3.html", width='100%', height='550px')
# Out:
#         <iframe
#             width="100%"
#             height="550px"
#             src="newsgroups_graph_s3.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
