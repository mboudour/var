# %% [markdown]
# # Patterns of bibliographic diversity in post-2022 publications on *LLMs* and *ChatGPT*
#
# ## Moses Boudourides
#
# ### SPS Data Science Program, Northwestern University
#
# ## Work in progress with Evan Piepho

# %%
import pandas as pd
from IPython.display import IFrame
from IPython.display import Image, display
from IPython.core.display import HTML

# %%
IFrame("dataShape.html", width=1000, height=250)
# Out:
#         <iframe
#             width="1000"
#             height="250"
#             src="dataShape.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_by_week.html", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_by_week.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_by_month.html", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_by_month.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubsDistGenderCompo.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubsDistGenderCompo.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_authors_gender_composition_by_week.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_authors_gender_composition_by_week.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_authors_gender_composition_by_week2.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_authors_gender_composition_by_week2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("typesDist.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="typesDist.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_types_by_week.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_types_by_week.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("OAtypesDistpie.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="OAtypesDistpie.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_oa_types_by_week.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_oa_types_by_week.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
display(Image(filename='categories_wordcloud.png', width=1200)) #, height=600))

# %%
# IFrame("raDistbar.html",width=800, height=800)
display(Image(filename='apl_d.png', width=1200)) #, height=600))

# %%
# IFrame("raWaklyEvol.html",width=800, height=800)
display(Image(filename='raWaklyEvol.png', width=1200)) #, height=600))

# %%
IFrame("grants_all&female_by_active_years.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="grants_all&female_by_active_years.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("grants_all&female_by_funders.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="grants_all&female_by_funders.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("funders_female&all_by_funding_amount.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="funders_female&all_by_funding_amount.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
display(Image(filename='Top10MostCitedPublications.png', width=1200)) #, height=600))

# %%
IFrame("pubs_researchAreasVStimesCited.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_researchAreasVStimesCited.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("pubs_journalsVStimesCited.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="pubs_journalsVStimesCited.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
display(Image(filename='Top10Funders.png', width=1200)) #, height=600))

# %%
IFrame("fundersByCountry.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="fundersByCountry.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame("publicationsVStotalFunding_usd.html",width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="publicationsVStotalFunding_usd.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
